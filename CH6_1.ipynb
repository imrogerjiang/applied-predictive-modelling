# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from scipy.stats import boxcox
from scipy.special import inv_boxcox
from scipy.stats import norm

# %%
def qq_plot(x):
    n = len(x)
    x = pd.Series(x)
    sample = ((x - x.mean())/x.std()).sort_values(ascending=True)
    theoretical = [norm.ppf((k+0.5)/n) for k in range(n)]
    plt.scatter(x=theoretical,y=sample)
    plt.axline((0,0), slope=1, color="darksalmon")
    plt.show()

# %%
# preprocessing
def normalise(df):
    return (df - df.mean())/df.std()

def boxcox_transform(df, lambdas=None):
    bc = pd.DataFrame()
    bc_lambdas = []
    for i, c in enumerate(df.columns):
        if lambdas is None:
            a, b = boxcox(df[c])
            bc_lambdas.append(b)
        else:
            a = boxcox(df[c], lmbda=lambdas[i])
        a = pd.Series(a, name=c, index=df.index)
        bc = pd.concat([bc, a], axis="columns")
    return bc, bc_lambdas

# %% [markdown]
# ## 6.1
#
# **The theory of IR spectroscopy holds that unique molecular structures absorb IR frequencies differently. In practice a spectrometer fires a series of IR frequencies into a sample material, and the device measures the absorbance of the sample at each individual frequency. This series of measurements creates a spectrum profile which can then be used to determine the chemical makeup of the sample material.**
#
# **A Tecator Infratec Food and Feed Analyzer instrument was used to analyze 215 samples of meat across 100 frequencies. A sample of these frequency profiles is displayed in Fig. 6.20. In addition to an IR profile, analytical chemistry determined the percent content of water, fat, and protein for each sample.**
#
# **(a) Load the data**
#
# **(b) In this example the predictors are the measurements at the individual fre-quencies. Because the frequencies lie in a systematic order (850–1,050 nm), the predictors have a high degree of correlation. Hence, the data lie in a smaller dimension than the total number of predictors (100). Use PCA to determine the effective dimension of these data. What is the effective dimension?**
#
# Variance explained by first 10 components of PCA\
# 0 - 26.1271\
# 1 - 0.2385\
# 2 - 0.0784\
# 3 - 0.0302\
# 4 - 0.0015\
# 5 - 0.0007\
# 6 - 0.0002\
# 7 - 0.0001\
# 8 - 0.0000\
# 9 - 0.0000
#
# Used boxcox transform and normalisation to reduce skewness. Variation explained remains same ratio.
#
# The effective dimention of PCA is 1.
#
# **(c) Split the data into a training and a test set, pre-process the data, and build each variety of models described in this chapter. For those models with tuning parameters, what are the optimal values of the tuning parameter(s)?**
#
# **(d) Which model has the best predictive ability? Is any model significantly better or worse than the others?**
#
# The boxcox transformation on predictor variables significantly improves the predictive ability for all models tested (ols, pcr, pls, l1 and l2 penalised regression)
#
# The performance of models is a function of the train/val/test split. I performed 300 bootstraps of the training dataset to find the performance independent of train/val/test split.
#
# Out of all the models, l2 penalised regression after boxcox transformation is consistently better than all the other alternatives. The performance at every quartile range was better for l2 penalised regression than any other model.
#
#
# **(e) Explain which model you would use for predicting the fat content of a sample.**
#
# L2 penalised regression after boxcox transformation.

# %%
# Reading in data

absorb = pd.read_csv("/home/roger/code/applied-predictive-modeling/data/absorb.csv", index_col="id", header=0)
endpoints = pd.read_csv("/home/roger/code/applied-predictive-modeling/data/endpoints.csv", index_col="id", header=0)
endpoints=endpoints.rename(columns=
    {"V2":"fat"})
absorb = pd.concat([absorb, endpoints[["fat"]]], axis="columns")

# %%
pca = PCA()
pca.fit(absorb.drop(columns="fat"))
# Out:
# PCA()

# %%
print("Total:", pca.explained_variance_.sum())
for i, var in enumerate(pca.explained_variance_[:10]):
    print(i, f"{var:.4f}")
# Out:
# Total: 26.476848832131623
# 0 26.1271
# 1 0.2385
# 2 0.0784
# 3 0.0302
# 4 0.0015
# 5 0.0007
# 6 0.0002
# 7 0.0001
# 8 0.0000
# 9 0.0000

# %%
absorb_n = (absorb - absorb.mean())/absorb.std()
absorb_n["fat"] = absorb["fat"]

# %%
pca_n = PCA()
pca_n.fit(absorb_n.drop(columns="fat"))
# Out:
# PCA()

# %%
for i, var in enumerate(pca.explained_variance_[:10]):
    print(i, f"{var:.4f}")
# Out:
# 0 26.1271
# 1 0.2385
# 2 0.0784
# 3 0.0302
# 4 0.0015
# 5 0.0007
# 6 0.0002
# 7 0.0001
# 8 0.0000
# 9 0.0000

# %%
# qq plot for untransformed variable
qq_plot(absorb_n["V1"])

# %%
# qq plot for box cox transformed variable
x_bc, l = boxcox(absorb["V1"])
qq_plot(x_bc)

# %%
# use boxcox to transform all variables, what effect does this have on PCA?

absorb_bc = pd.DataFrame()
bc_lambdas = []
for c in absorb.columns:
    a, b = boxcox(absorb[c])
    a = pd.Series(a, name=c, index=absorb.index)
    absorb_bc = pd.concat([absorb_bc, a], axis="columns")
    bc_lambdas.append(b)
absorb_bc["fat"] = absorb["fat"]

# %%
pca_bc = PCA()
pca_bc.fit(absorb_bc.drop(columns="fat"))
# Out:
# PCA()

# %%
for i, var in enumerate(pca_bc.explained_variance_[:10]):
    print(i, f"{var:.4f}")
# Out:
# 0 0.1585
# 1 0.0012
# 2 0.0004
# 3 0.0001
# 4 0.0000
# 5 0.0000
# 6 0.0000
# 7 0.0000
# 8 0.0000
# 9 0.0000

# %%
# With/without standardisation + boxcox
# Ordinary Least Squares
# PCA
# PLS
# squared regularisation
# abs regularisation

# %%
# checking for patterns in target variable
# looks like data is not randomised
plt.scatter(x=range(len(absorb["fat"])), y=absorb["fat"])
plt.show()

# %%
# training/validation/test
no_transform = {}

no_transform["train_val"], no_transform["test"] = train_test_split(absorb, test_size=0.2)
no_transform["train"], no_transform["val"] = train_test_split(no_transform["train_val"], test_size=0.25)

y = {}
for key in no_transform:
    y[key] = no_transform[key]["fat"]
    no_transform[key] = no_transform[key].drop(columns="fat")

# %%
normalised = {}
for key in no_transform:
    normalised[key] = normalise(no_transform[key])

bc_transformed = {}
bc_transformed["train"], lambdas = boxcox_transform(no_transform["train"])
for key in [e for e in no_transform if e != "train"]:
    bc_transformed[key], _ = boxcox_transform(no_transform[key], lambdas)

# %%
# Ordinary Least Squares
ols_no_preprocessing = linear_model.LinearRegression()
ols_normalise = linear_model.LinearRegression(normalize=True)
ols_boxcox = linear_model.LinearRegression(normalize=True)

# %%
# Training
ols_no_preprocessing.fit(X=no_transform["train_val"], y=y["train_val"])
ols_normalise.fit(X=no_transform["train_val"], y=y["train_val"])
ols_boxcox.fit(X=bc_transformed["train_val"], y=y["train_val"])
# Out:
# LinearRegression(normalize=True)

# %%
# Testing
print(f'Ordinary Least Squares without preprocessing R2: {ols_no_preprocessing.score(X=no_transform["test"], y=y["test"]):.4f}')
print(f'Ordinary Least Squares with normalisation R2: {ols_normalise.score(X=no_transform["test"], y=y["test"]):.4f}')

# boxcox transform
print(f'Ordinary Least Squares with norm & boxcox R2: {ols_boxcox.score(X=bc_transformed["test"], y=y["test"]):.4f}')
# Out:
# Ordinary Least Squares without preprocessing R2: 0.8204
# Ordinary Least Squares with normalisation R2: 0.8204
# Ordinary Least Squares with norm & boxcox R2: 0.9569

# %%
pca_scores = []

for n_components in range(1, min(bc_transformed["train"].shape)-1):
    pca_x = {}
    pca = PCA(n_components=n_components)
    ols_pca = linear_model.LinearRegression()

    pca_x["train"] = pca.fit_transform(bc_transformed["train"])
    pca_x["val"] = pca.transform(bc_transformed["val"])
    pca_x["test"] = pca.transform(bc_transformed["test"])

    ols_pca.fit(X=pca_x["train"], y=y["train"])
    pca_scores.append(ols_pca.score(X=pca_x["val"], y=y["val"]))
    
n = pca_scores.index(max(pca_scores))+1
pca_final = PCA(n_components=n)
pca_x["train_val"] = pca_final.fit_transform(bc_transformed["train_val"])
pca_x["test"] = pca_final.transform(bc_transformed["test"])
ols_pca.fit(pca_x["train_val"], y["train_val"])

print(f'pca test score {ols_pca.score(pca_x["test"], y["test"]):.4f}')
# Out:
# pca test score 0.9776

# %%
# PLS
# Loop through top X components
# Fit regression
# Find R2 on test set
# Graph
pls_scores = []

for n_components in range(1, min(bc_transformed["train"].shape)-1):
    pls = PLSRegression(n_components=n_components)

    pls_x = {}
    pls.fit(bc_transformed["train"], y["train"])
    pls_scores.append(pls.score(X=bc_transformed["val"], y=y["val"]))

# Select number of components with highest R2 score
# Fit regression on training and validation set
# Score on test set
n = pls_scores.index(max(pls_scores))+1
pls_final = PLSRegression(n_components=n)
pls.fit(bc_transformed["train_val"], y["train_val"])
print(f'pls test score {pls.score(X=bc_transformed["test"], y=y["test"]):.4f}')
# Out:
# pls test score 0.9569

# %%
# Penalised Regression

alphas = []
scores_l1 = []
scores_l2 = []
for i in range(-30, 0):
    alpha = 10**(i/4)
    alphas.append(alpha)
    ols_l1 = linear_model.Lasso(alpha=alpha, max_iter=10_000)
    ols_l2 = linear_model.Ridge(alpha=alpha, max_iter=10_000)
    ols_l1.fit(bc_transformed["train"], y["train"])
    ols_l2.fit(bc_transformed["train"], y["train"])
    scores_l1.append(ols_l1.score(bc_transformed["val"], y["val"]))
    scores_l2.append(ols_l2.score(bc_transformed["val"], y["val"]))

alpha_l1 = alphas[scores_l1.index(max(scores_l1))]
alpha_l2 = alphas[scores_l2.index(max(scores_l2))]
ols_l1 = linear_model.Lasso(alpha=alpha_l1, max_iter=10_000)
ols_l2 = linear_model.Ridge(alpha=alpha_l2, max_iter=10_000)
ols_l1.fit(bc_transformed["train_val"], y["train_val"])
ols_l2.fit(bc_transformed["train_val"], y["train_val"])
print(f'l1 regularisation: {ols_l1.score(bc_transformed["test"], y["test"])}')
print(f'l2 regularisation: {ols_l2.score(bc_transformed["test"], y["test"])}')
# Out:
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 552.232487448753, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 552.2142085281138, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 552.1816922927308, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 552.123816552808, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 552.0206855990317, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 551.8364071915544, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 551.5053954368753, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 550.9110958681966, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 549.8464786348255, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 547.8597822281159, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 543.9661757866338, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 534.4168276207023, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 515.5887511958139, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 448.08539126139306, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 306.5897944042953, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 212.8922058402934, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92.58441983260047, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80.97451055532827, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 63.05450618244981, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.49293839874713, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.532652773426662, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.901218762498956, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.059307954520591, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.503750686660624, tolerance: 2.12826303875969
#   model = cd_fast.enet_coordinate_descent(
# l1 regularisation: 0.9234142148934582
# l2 regularisation: 0.9790229566840396
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 752.7815810476146, tolerance: 2.8100504360465117
#   model = cd_fast.enet_coordinate_descent(

# %%
# Boostrapping R2 with different train/val/test splits
# Creating split
train_val, test = train_test_split(absorb, test_size=0.2)
train, val = train_test_split(train_val, test_size=0.25)
ds = {}
ds["x_train"] = train.drop(columns="fat")
ds["x_val"] = val.drop(columns="fat")
ds["x_train_val"] = train_val.drop(columns="fat")
ds["x_test"] = test.drop(columns="fat")
ds["y_train"] = train["fat"]
ds["y_val"] = val["fat"]
ds["y_train_val"] = train_val["fat"]
ds["y_test"] = test["fat"]

# %%
def ols(ds):
    ols = linear_model.LinearRegression()
    ols.fit(X=ds["x_train_val"], y=ds["y_train_val"])
    return ols.score(X=ds["x_test"], y=ds["y_test"])

# %%
ols(ds)
# Out:
# 0.8791459111177173

# %%
def ols_bc(ds):
    ols_boxcox = linear_model.LinearRegression(normalize=True)
    train_val_bc, lambdas = boxcox_transform(ds["x_train_val"])
    ols_boxcox.fit(X=train_val_bc, y=ds["y_train_val"])
    test_bc, _ = boxcox_transform(ds["x_test"], lambdas=lambdas)
    return ols_boxcox.score(X=test_bc, y=ds["y_test"])

# %%
ols_bc(ds)
# Out:
# 0.9817259357978549

# %%
def pca(ds, boxcox=False):
    pca_scores = []
    
    if boxcox:
        ds_bc = {}
        ds_bc["x_train"], lambdas = boxcox_transform(ds["x_train"])
        ds_bc["x_val"], _ = boxcox_transform(ds["x_val"], lambdas=lambdas)
        ds_bc["x_train_val"], lambdas = boxcox_transform(ds["x_train_val"])
        ds_bc["x_test"], _ = boxcox_transform(ds["x_test"], lambdas=lambdas)
    else:
        ds_bc = ds
    
    for n_components in range(1, min(ds_bc["x_train"].shape)-1):
        pca_x = {}
        pca = PCA(n_components=n_components)
        ols_pca = linear_model.LinearRegression()

        pca_x["train"] = pca.fit_transform(ds_bc["x_train"])
        pca_x["val"] = pca.transform(ds_bc["x_val"])
        pca_x["test"] = pca.transform(ds_bc["x_test"])

        ols_pca.fit(X=pca_x["train"], y=ds["y_train"])
        pca_scores.append(ols_pca.score(X=pca_x["val"], y=ds["y_val"]))

    n = pca_scores.index(max(pca_scores))+1
    pca_final = PCA(n_components=n)
    pca_x["train_val"] = pca_final.fit_transform(ds_bc["x_train_val"])
    pca_x["test"] = pca_final.transform(ds_bc["x_test"])
    ols_pca.fit(pca_x["train_val"], ds["y_train_val"])

    return ols_pca.score(pca_x["test"], ds["y_test"])

# %%
def pls(ds, boxcox=False):
    pls_scores = []

    if boxcox:
        ds_bc = {}
        ds_bc["x_train"], lambdas = boxcox_transform(ds["x_train"])
        ds_bc["x_val"], _ = boxcox_transform(ds["x_val"], lambdas=lambdas)
        ds_bc["x_train_val"], lambdas = boxcox_transform(ds["x_train_val"])
        ds_bc["x_test"], _ = boxcox_transform(ds["x_test"], lambdas=lambdas)
    else:
        ds_bc = ds
    
    for n_components in range(1, min(ds_bc["x_train"].shape)-1):
        pls = PLSRegression(n_components=n_components)
        ols_pls = linear_model.LinearRegression()

        pls_x = {}
        pls.fit(ds_bc["x_train"], ds["y_train"])
        pls_scores.append(pls.score(X=ds_bc["x_val"], y=ds["y_val"]))

    # Select number of components with highest R2 score
    # Fit regression on training and validation set
    # Score on test set
    n = pls_scores.index(max(pls_scores))+1
    pls_final = PLSRegression(n_components=n)
    pls_final.fit(ds_bc["x_train_val"], ds["y_train_val"])
    return pls_final.score(X=ds_bc["x_test"], y=ds["y_test"])

# %%
def penalised_regression(ds, model):
    ds_bc = {}
    ds_bc["x_train"], lambdas = boxcox_transform(ds["x_train"])
    ds_bc["x_val"], _ = boxcox_transform(ds["x_val"], lambdas=lambdas)
    ds_bc["x_train_val"], lambdas = boxcox_transform(ds["x_train_val"])
    ds_bc["x_test"], _ = boxcox_transform(ds["x_test"], lambdas=lambdas)
    
    scores = []
    alphas = [10**(i/4) for i in range(-30, 0)]
    for alpha in alphas:
        penalised_reg = model(alpha=alpha, max_iter=10_000)
        penalised_reg.fit(ds_bc["x_train"], ds["y_train"])
        scores.append(penalised_reg.score(ds_bc["x_val"], ds["y_val"]))

    best_alpha = alphas[scores.index(max(scores))]
    final_model = model(alpha=best_alpha, max_iter=10_000)
    final_model.fit(ds_bc["x_train_val"], ds["y_train_val"])
    return final_model.score(ds_bc["x_test"], ds["y_test"])

# %%
# Main bootstrap loop
# Sample train/val/test datasets from absorb
# Todo: Try adding boxcox to pca/pls
# Todo: Add way to record hyperparameters

trials = 300
results = pd.DataFrame()

for i in range(trials):
    train_val, test = train_test_split(absorb, test_size=0.2)
    train, val = train_test_split(train_val, test_size=0.25)
    ds = {}
    ds["x_train"] = train.drop(columns="fat")
    ds["x_val"] = val.drop(columns="fat")
    ds["x_train_val"] = train_val.drop(columns="fat")
    ds["x_test"] = test.drop(columns="fat")
    ds["y_train"] = train["fat"]
    ds["y_val"] = val["fat"]
    ds["y_train_val"] = train_val["fat"]
    ds["y_test"] = test["fat"]

    results = results.append({
        "ols":ols(ds),
        "ols_bc": ols_bc(ds),
        "pca": pca(ds),
        "pca_bc": pca(ds, boxcox=True),
        "pls": pls(ds),
        "pls_bc": pls(ds, boxcox=True),
        "l1": penalised_regression(ds, linear_model.Lasso),
        "l2": penalised_regression(ds, linear_model.Ridge)
    }, ignore_index=True)
    print(i)
# Out:
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 546.8871434889173, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 546.8919270854237, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 546.9004660250707, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 546.915724702186, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 546.9430015509346, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 546.9916203659803, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 547.0774651006301, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 547.2243520794195, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 547.4704590060345, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 547.8324234061577, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 548.165552166647, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 548.4870443394059, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 545.6890999337226, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 531.9434379054583, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 476.7431848873703, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 205.23697584872446, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 129.60013197943704, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.04441034351748, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65.854745405612, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52.44879582041449, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.408864666810814, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.093433307445594, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.351542837094712, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.387511249899035, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.18641627785928, tolerance: 1.9590160155038758
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106.18642330406783, tolerance: 2.5727317906976745
#   model = cd_fast.enet_coordinate_descent(
# 0
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586.7283541401656, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586.7322310681933, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586.739051666692, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586.750948720538, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586.7712891200507, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586.8047277551336, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586.8583941399245, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586.9301487371949, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586.9808273531141, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586.7544975074454, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 585.266650882331, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 578.5569829189285, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 551.123738623277, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 449.86631705633624, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140.8786066756719, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110.34476431612131, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86.01859174536094, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55.565348269678225, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.75400699755937, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.028525767789688, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.208211886687423, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.726244006710658, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.927367026279626, tolerance: 1.985717968992248
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.77785012817617, tolerance: 2.6347328546511632
#   model = cd_fast.enet_coordinate_descent(
# 1
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 643.2075515582846, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 643.1877614427661, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 643.1525299199403, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 643.0897548241227, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 642.9777232764569, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 642.7762861714991, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 642.4214166877931, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 641.7769255115818, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 640.640133464481, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 638.563850875759, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 634.4533872134726, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 626.5151623373484, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 604.2639783547406, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 539.9736704334205, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 201.87611861924324, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122.46239976361983, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98.97616927401555, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83.51623984678918, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64.77560043499875, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.651183996360032, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.726960787994585, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.715721922666944, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.598453853857791, tolerance: 2.080852387596899
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115.77490565316043, tolerance: 2.830515162790698
#   model = cd_fast.enet_coordinate_descent(
# 2
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 520.9874404257167, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 520.9755210557217, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 520.9542842103796, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 520.9164231045115, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 520.8490446922765, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 520.7264985972472, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 520.5025948531915, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 520.0779707099439, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 519.2545553037711, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 517.4831381963728, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 513.2226005986499, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 502.08358982851263, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 468.1997617655239, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 393.87340404998827, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 195.35144192028918, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 208.03615107947428, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.7727468181688, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75.80929556546891, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61.077337960795376, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.391812845127788, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.16705691896459, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.517400018349235, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.488843473192901, tolerance: 1.9354277209302329
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 644.9289651028395, tolerance: 2.686748976744186
#   model = cd_fast.enet_coordinate_descent(
# 3
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 630.2054681058935, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 630.182816224505, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 630.1422839015158, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 630.0694596207901, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 629.937313950138, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 629.6943893451411, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 629.2380539355759, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 628.3472721812471, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 626.5878059446338, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 622.6771048869815, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 613.4015970691215, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 588.414980964927, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 500.9358005908829, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276.1585232777082, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115.96435574631073, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97.23906522025982, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78.32811509272506, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57.87664117709846, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.682501692327605, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.600363569072215, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.422442325588236, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.73973434306663, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.296523947030437, tolerance: 2.255573488372093
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 761.9165369732689, tolerance: 2.906836162790698
#   model = cd_fast.enet_coordinate_descent(
# 4
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 600.2568784133806, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 600.260291965666, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 600.2663356533036, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 600.2770041563449, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 600.295703526183, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 600.3280891847556, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 600.3844746085666, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 600.4787510859484, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 600.5799815132235, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 600.6983284769005, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 600.6475110214477, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 599.5708700222457, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 594.5207973842173, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 573.5629030648367, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 492.98212754782793, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 272.96506416670053, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142.61759029230643, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94.02602455848682, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76.68937762219252, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50.79442658151629, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.641220813148266, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.043433268416493, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.397146448928197, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.422775027172065, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.9492160122699715, tolerance: 1.8602293953488374
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 598.2734364000582, tolerance: 2.540460511627907
#   model = cd_fast.enet_coordinate_descent(
# 5
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 589.0526590153645, tolerance: 2.086903596899225
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 589.052321597417, tolerance: 2.086903596899225
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 589.0515226835856, tolerance: 2.086903596899225
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 589.0497898183681, tolerance: 2.086903596899225
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 589.0467067670078, tolerance: 2.086903596899225
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 589.041206784714, tolerance: 2.086903596899225
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 589.0302652672725, tolerance: 2.086903596899225
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 589.0001786742403, tolerance: 2.086903596899225
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 588.8648570548443, tolerance: 2.086903596899225
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 509.071187510063, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 509.05100142463453, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 509.0143256553335, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 508.94659453011496, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 508.8312623029537, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 508.6165196541871, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 508.1866023556894, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 506.97987501214095, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 503.9398636909424, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 495.0060625418541, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 466.0798758426458, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 395.4717085420141, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 226.89919447329737, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 180.62729861188097, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113.87232570614287, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77.97244882405539, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.51256532167281, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.986753286281782, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.44573079765064, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.81982698650495, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.511984994991053, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2044497194729047, tolerance: 2.32103423255814
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 681.0320079236795, tolerance: 2.855223924418605
#   model = cd_fast.enet_coordinate_descent(
# 299
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 546.019852639886, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 546.0121745870132, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 545.9984760555878, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 545.9738904026344, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 545.9299233172002, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 545.851437391258, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 545.7081814779467, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 545.4572381662435, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 544.9690467829702, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 544.0745826460468, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 542.2548266494299, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 538.0750230742343, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 524.8309526300525, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 467.9365787540322, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 254.5438956203957, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116.91085202572629, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99.99970313770882, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72.54791904162391, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.98666013867273, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.946022389512564, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.557724984676724, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.6668753022299825, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.630567914306539, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.956591081976512, tolerance: 1.7684349922480622
#   model = cd_fast.enet_coordinate_descent(
# /home/roger/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134.9878894595115, tolerance: 2.764484162790698
#   model = cd_fast.enet_coordinate_descent(
# 300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11355/227116228.py in <module>
#      26         "pca_bc": pca(ds, boxcox=True),
#      27         "pls": pls(ds),
# ---> 28         "pls_bc": pls(ds, boxcox=True),
#      29         "l1": penalised_regression(ds, linear_model.Lasso),
#      30         "l2": penalised_regression(ds, linear_model.Ridge)
#
# /tmp/ipykernel_11355/4033780195.py in pls(ds, boxcox)
#      16
#      17         pls_x = {}
# ---> 18         pls.fit(ds_bc["x_train"], ds["y_train"])
#      19         pls_scores.append(pls.score(X=ds_bc["x_val"], y=ds["y_val"]))
#      20
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/cross_decomposition/_pls.py in fit(self, X, Y)
#     298             if self.deflation_mode == "regression":
#     299                 # regress Yk on x_score
# --> 300                 y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
#     301                 Yk -= np.outer(x_scores, y_loadings)
#     302
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
results.describe()
# Out:
#               ols      ols_bc         pca      pca_bc         pls      pls_bc  \
# count  301.000000  301.000000  301.000000  301.000000  301.000000  301.000000
# mean     0.910375    0.968194    0.940786    0.981436    0.944724    0.981196
# std      0.076409    0.017504    0.048014    0.008217    0.043354    0.008554
# min      0.509674    0.883354    0.486928    0.945585    0.523644    0.939264
# 25%      0.885112    0.962394    0.933721    0.977846    0.938104    0.977682
# 50%      0.935076    0.972858    0.955182    0.983277    0.958679    0.982786
# 75%      0.961541    0.980184    0.966349    0.986976    0.967455    0.986871
# max      0.987882    0.990584    0.986145    0.994747    0.986802    0.993969
#
#                l1          l2
# count  301.000000  301.000000
# mean     0.936133    0.982449
# std      0.019796    0.007478
# min      0.838045    0.949295
# 25%      0.927505    0.979598
# 50%      0.938926    0.984084
# 75%      0.948606    0.987492
# max      0.971139    0.994928
